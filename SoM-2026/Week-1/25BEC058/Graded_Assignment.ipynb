# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df = pd.read_csv("W1_Pokemon.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
np.array(df.columns)
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation',
#        'Legendary'], dtype=object)

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
df = df.drop(columns= "#")
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
df.set_index("Name",inplace=True)
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
list(df["Type 1"].unique())
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying']

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
for i,j in zip(df["Type 1"],df["Type 2"]):
    if(i == "Psychic" and j == "Flying"):
        df['NEW'] = df['Type 1'] + '+' + df['Type 2'] + " " + "Psychic : 1, Flying : 1"
    if(i == "Psychic" and j != "Flying"):
        df['NEW'] = df['Type 1'] + '+' + df['Type 2'] + " " + "Psychic : 1, Flying : 0"
    if(i != "Psychic" and j == "Flying"):
        df['NEW'] = df['Type 1'] + '+' + df['Type 2'] + " " + "Psychic : 0, Flying : 1"
    if(i != "Psychic" and j != "Flying"):
        df['NEW'] = df['Type 1'] + '+' + df['Type 2'] + " " + "Psychic : 0, Flying : 0"
    
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary  \
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False
#
#                                                         NEW
# Name
# Bulbasaur              Grass+Poison Psychic : 0, Flying : 0
# ...

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
ct = 0
for i in df.index:
    if("Mega" in i):
        ct+=1
print(ct)
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
df["Sp. Def"].std()
# Out:
# 27.82891579711745

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
ct = 0
for i in df["Legendary"]:
    if(i == True):
        ct+=1
    
p = round(((ct/800) * 100),3)

p
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
for i in df[df["Defense"] == df["Defense"].max()].index:
    
    print(i)
# Out:
# SteelixMega Steelix
# Shuckle
# AggronMega Aggron

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
df1 = df[(df["Type 1"] == "Poison") | (df["Type 2"] == "Poison")].sort_values("Attack",ascending =False)
list(df1[df1["Attack"] == df1["Attack"].max()].index)
# Out:
# ['BeedrillMega Beedrill']

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('W1_Pokemon.csv')


type_totals = df.groupby('Type 1')['Total'].mean().reset_index()


type_totals = type_totals.sort_values('Total', ascending=False)


sns.set(style="whitegrid")


plt.figure(figsize=(12, 6))
ax = sns.barplot(data=type_totals, x='Type 1', y='Total', palette='Set2')


plt.title('Average Total Stats by Primary Pokémon Type')
plt.xlabel('Primary Type')
plt.ylabel('Average Total Stat')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\tiwar_z5dvqky\AppData\Local\Temp\ipykernel_8296\4112247404.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=type_totals, x='Type 1', y='Total', palette='Set2')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('W1_Pokemon.csv')


sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
ax = sns.scatterplot(
    data=df,
    x='Speed',
    y='Total',
    hue='Legendary',
    palette='Set1',
    alpha=0.7
)


plt.title('Pokémon: Total Stats vs. Speed')
plt.xlabel('Speed')
plt.ylabel('Total Stats')
plt.legend(title='Legendary')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('W1_Pokemon.csv')

# Calculate Generation-wise average for Total stats
gen_avg = df.groupby("Generation")["Total"].mean().reset_index()


sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.lineplot(data=gen_avg, x='Generation', y='Total', marker='o', color='mediumseagreen')

plt.title('Average Total Stats by Pokémon Generation')
plt.xlabel('Generation')
plt.ylabel('Average Total Stats')
plt.xticks(gen_avg['Generation'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
ax = df[(df["Legendary"] == False) & (df["Generation"] == 4) & ((df["Type 1"] == "Ghost") | (df["Type 2"] == "Ghost"))].sort_values("Speed",ascending =False)
plt.Figure(figsize=(20,5))
ax = ax.reset_index()
sns.barplot(x="Name",y="Speed",data=ax)
plt.yticks(np.arange(0,111,5))
plt.title("Speed of Non Legendary 'Ghost' Type Pokemon from 4th Gen")
plt.show()

print("Second Fastest : ",ax["Name"][1])
# Out:
# Second Fastest :  Mismagius

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
ax1 = df[df["Legendary"] == False].reset_index()
chari = ax1[ax1["Name"] == "Charizard"].iloc[0]
plt.figure(figsize=(15,10))
filtered = ax1[(ax1["Attack"] < chari["Attack"]) & (ax1["Defense"] > chari["Defense"])]
ax2 = sns.scatterplot(x="Attack",y="Defense",data=ax1,alpha=0.7,color="blue")
sns.scatterplot(x="Attack",y="Defense",data=filtered,alpha=0.7,color="red",label="Qulifies")
ax2.axvline(x=chari["Attack"],color ="red",linestyle="-.")
ax2.axhline(y=chari["Defense"],color ="red",linestyle="-.")
plt.title("Non-Legendary Pokemons Attack and Defense compared to Charizard")
plt.show()

print("The Non-Legendary Pokemon that have stronger defense and weaker attack than Charizard are",len(filtered))
# Out:
# The Non-Legendary Pokemon that have stronger defense and weaker attack than Charizard are 116

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
df["Combined"] = df["Attack"] + df["Sp. Atk"]
list(df[df["Combined"] == df["Combined"].max()].index)
# Out:
# [426, 429]

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
"Type 1 : " + df[df["Legendary"] == True]["Type 1"].value_counts().idxmax() + " Type 2 : "  + df[df["Legendary"] == True]["Type 2"].value_counts().idxmax()
# Out:
# 'Type 1 : Psychic Type 2 : Flying'

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
weak = int(df[(df["Legendary"] == True) & (df["Generation"] == 6)].sort_values("HP").head(1)["HP"])
loop = df[(df["Legendary"] == False) & (df["Generation"] == 3)]["HP"]
ct = 0
for x in loop:
    if(x > weak):
        ct+=1
print(ct)
# Out:
# 95
# C:\Users\tiwar_z5dvqky\AppData\Local\Temp\ipykernel_8296\1847267516.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   weak = int(df[(df["Legendary"] == True) & (df["Generation"] == 6)].sort_values("HP").head(1)["HP"])

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
p = df["Speed"].unique()
p.sort()
slow = int(p[2])
list(df[df["Speed"] == slow].index)
# Out:
# [85, 187, 188, 209, 219, 289, 291, 583, 651]

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
"Type 1 : " + df.groupby("Type 1")["HP"].mean().idxmax() + " Type 2 : " + df.groupby("Type 2")["HP"].mean().idxmax()
# Out:
# 'Type 1 : Dragon Type 2 : Ice'
