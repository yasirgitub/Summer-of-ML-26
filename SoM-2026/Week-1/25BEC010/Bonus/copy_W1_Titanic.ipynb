# %% [markdown]
# <a href="https://colab.research.google.com/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Week-1 Assignment
#
# # Titanic: Survival Analysis
#
# **Welcome to your first bonus assignment! The dataset you'll be working with is the legendary Titanic passenger dataset - one of the most famous datasets in data science.**
#
# **The Titanic sank on April 15, 1912 after colliding with an iceberg. Of 2,224 passengers and crew aboard, only 710 survived. This dataset captures information about 891 of those passengers and your job is to explore it using Pandas and data visualization.**
#
# **We have a set of questions for you that will build your understanding of data manipulation and visualization. GOOD LUCK!**
#
# ---
#
# **Dataset columns:**
# | Column | Description |
# |--------|-------------|
# | PassengerId | Unique ID for each passenger |
# | Survived | 0 = Did not survive, 1 = Survived |
# | Pclass | Ticket class (1 = 1st, 2 = 2nd, 3 = 3rd) |
# | Name | Passenger name |
# | Sex | Gender |
# | Age | Age in years |
# | SibSp | # of siblings/spouses aboard |
# | Parch | # of parents/children aboard |
# | Ticket | Ticket number |
# | Fare | Passenger fare |
# | Cabin | Cabin number |
# | Embarked | Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton) |
#
# ---
#
# *Let's get started with importing numpy, pandas, seaborn and matplotlib!*
#
# **Note** - matplotlib should be imported with the command:
#
# `import matplotlib.pyplot as plt`

# %% [markdown]
# ## Warm-Up Questions
#
# These questions are **ungraded** and help you get comfortable with the dataset.

# %% [markdown]
# ### 1) Import all important libraries
# Import `numpy`, `pandas`, `seaborn`, and `matplotlib.pyplot`.

# %%
# your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the CSV file and assign it to a variable
# Load `W1_Titanic.csv` into a DataFrame.

# %%
# your code here
df=pd.read_csv('../../Bonus/W1_Titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 3) Display the shape of the DataFrame
# Expected Output: `(891, 12)`

# %%
# your code here
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 4) Print all column names of the DataFrame
# Return an array/index containing the names of all columns.

# %%
# your code here
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 5) Display the first 5 rows and the data types of each column
# Use `.head()` and `.dtypes`.

# %%
# your code here
df.head()
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### 6) Check for missing values
# Print the count of missing values in each column.
#
# *Hint: use `.isnull().sum()`*

# %%
# your code here
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 7) Set `PassengerId` as the index of the DataFrame
# Update the DataFrame in-place.

# %%
# your code here
df.set_index('PassengerId', inplace=True)
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 8) Create a new column `FamilySize` = `SibSp` + `Parch` + 1
# This represents the total number of family members aboard (including the passenger themselves).

# %%
# your code here
df['FamilySize']=df['SibSp']+df['Parch']+1
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              FamilySize
# PassengerId
# 1                     2
# 2                     2
# 3                     1
# 4                     2
# 5                     1

# %% [markdown]
# ## GRADED Questions
#
# ### Answer these questions in the quiz. BEST OF LUCK!!

# %% [markdown]
# ### 1. How many passengers survived?

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
df['Survived'].sum()
# Out:
# np.int64(342)

# %% [markdown]
# ### 2. What is the average age of passengers who survived vs. those who did not?
#
# *Hint: Use `groupby` on the `Survived` column, then take the mean of `Age`.*
#
# *Note: Round your answer to 2 decimal places.*

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
print(df[df['Survived']==1]['Age'].mean())
print(df[df['Survived']==0]['Age'].mean())
# Out:
# 28.343689655172415
# 30.62617924528302

# %% [markdown]
# ### 3. What percentage (up to 2 decimal places) of female passengers survived?

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
round((df[(df['Sex']=='female') & (df['Survived']==1)].shape[0] / df[df['Sex']=='female'].shape[0]) * 100, 2)
# Out:
# 74.2

# %% [markdown]
# ### 4. Which passenger class (Pclass) had the highest survival rate?
#
# *Hint: Group by `Pclass` and find the mean of `Survived` for each class.*

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
c1=df[(df['Pclass']==1)]['Survived'].mean()
c2=df[(df['Pclass']==2)]['Survived'].mean()
c3=df[(df['Pclass']==3)]['Survived'].mean()
if(c1>c2 and c1>c3):
    print('Pclass 1 had the highest survival rate')
elif(c2>c1 and c2>c3):
    print('Pclass 2 had the highest survival rate')
else:
    print('Pclass 3 had the highest survival rate')
# Out:
# Pclass 1 had the highest survival rate

# %% [markdown]
# ### 5. What is the name of the passenger who paid the highest fare?

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
f=df['Fare'].max()
print(df[df['Fare']==f]['Name'].values[0])
# Out:
# Ward, Miss. Anna

# %% [markdown]
# ### 6. Using seaborn, make the following plots, observe the trends, and answer the questions given in the form.
#
# **Plot A** — Survival count by passenger class (bar plot)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('W1_Titanic.csv')

sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set1')

plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **Plot B** — Age distribution of survivors vs. non-survivors (histogram / KDE plot)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('W1_Titanic.csv')

sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Age', hue='Survived', kde=True, palette='Set2', bins=30)

plt.title('Age Distribution: Survivors vs. Non-Survivors')
plt.xlabel('Age')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Plot C** — Average fare by embarkation port (bar plot) — *Complete the missing line*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('W1_Titanic.csv')

# Calculate average fare grouped by embarkation port
avg_fare = df.groupby('Embarked')['Fare'].mean().reset_index() 

sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
sns.barplot(data=avg_fare, x='Embarked', y='Fare', palette='muted')

plt.title('Average Fare by Port of Embarkation')
plt.xlabel('Port (C = Cherbourg, Q = Queenstown, S = Southampton)')
plt.ylabel('Average Fare')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_17844\2608572112.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_fare, x='Embarked', y='Fare', palette='muted')

# %% [markdown]
# ### 7. Among male passengers in 3rd class, how many survived?

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
df[(df['Sex']=='male') & (df['Survived']==1) & (df['Pclass']==3)].shape[0]
# Out:
# 47

# %% [markdown]
# ### 8. How many passengers under the age of 10 were on board, and what fraction of them survived?
#
# *Note: Ignore passengers with missing Age values. Round the fraction to 2 decimal places.*

# %%
import pandas as pd
df = pd.read_csv('W1_Titanic.csv')

# your code here
tp=df[df['Age']<10].shape[0]
print(tp)
fr=(df[(df['Age']<10) & (df['Survived']==1)].shape[0])/tp
print(str(round(fr*100, 2))+'%')
# Out:
# 62
# 61.29%

# %% [markdown]
# ---
#
# ## Bonus Questions
#
# ### These are UNGRADED and are given as an extra challenge.
#
# ---

# %% [markdown]
# ### Which cabin deck (first letter of the Cabin column, e.g. 'C' for 'C85') had the highest survival rate?
#
# *Hint: Extract the first character of the `Cabin` column after dropping rows where `Cabin` is null.*

# %%
# your code here
df1=df[df['Cabin'].notna()].copy()
df1['Deck']=df1['Cabin'].str[0]

df1.groupby('Deck')['Survived'].mean().idxmax()
# Out:
# 'D'

# %% [markdown]
# ### Extract titles from passenger names (e.g. 'Mr', 'Mrs', 'Miss') and find the most common title among survivors.
#
# *Hint: The Name column looks like `Braund, Mr. Owen Harris` — extract the word between `, ` and `.`*

# %%
# your code here
survivors=df[df['Survived'] == 1].copy()
survivors['Title']=survivors['Name'].str.extract(r',\s*([^\.]+)\.', expand=False)
survivors['Title'].value_counts().idxmax()
# Out:
# 'Miss'

# %% [markdown]
# ### Plot a heatmap of the correlation matrix of all numeric columns.
#
# *Use `seaborn.heatmap` with `annot=True`. Which two features are most positively correlated?*

# %%
# your code here
import seaborn as sns
import matplotlib.pyplot as plt

corr=df.select_dtypes(include='number').corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

corr_no_self=corr.where(~(corr==1.0))
max_pair=corr_no_self.stack().idxmax()
max_value=corr_no_self.stack().max()

max_pair, max_value
# Out:
# (('SibSp', 'Parch'), 0.41483769862015624)

# %% [markdown]
# ### Among passengers travelling alone (FamilySize == 1), what was the survival rate compared to those with family?
#
# *You'll need to first create the `FamilySize` column (from the warm-up), then group.*

# %%
# your code here
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

alone_rate = df[df['FamilySize'] == 1]['Survived'].mean() * 100
with_family_rate = df[df['FamilySize'] > 1]['Survived'].mean() * 100
alone_rate, with_family_rate
# Out:
# (np.float64(30.353817504655495), np.float64(50.56497175141242))

# %% [markdown]
# ### Which age group (bin them in 10-year intervals: 0-10, 10-20, 20-30, ...) had the lowest survival rate?

# %%
# your code here
age_df = df[df['Age'].notna()].copy()
age_df['AgeGroup'] = pd.cut(age_df['Age'], bins=range(0, 91, 10), right=False)

age_df.groupby('AgeGroup')['Survived'].mean().idxmin()
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_17844\593500851.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_df.groupby('AgeGroup')['Survived'].mean().idxmin()
# Interval(70, 80, closed='left')
