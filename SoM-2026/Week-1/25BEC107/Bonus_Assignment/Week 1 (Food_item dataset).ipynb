# %% [markdown]
# ### 1) Import Pandas and Numpy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Import the dataset and  Assign it to a variable called Chipo
#
# #### Import the dataset from
# https://github.com/justmarkham/pandas-videos/blob/master/data/chipotle.tsv
#
# #### REMEMBER: It is a .tsv file , you will have to do some research on how to read .tsv files first!

# %%
Chipo=pd.read_csv('https://github.com/justmarkham/pandas-videos/raw/master/data/chipotle.tsv',sep='\t')

# %% [markdown]
# ### 3) See the first 10 entries

# %%
Chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### 4) What is the number of observations in the dataset?

# %%
Chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# ### 5) What is the number of columns in the dataset?

# %%
Chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### 6) Print the name of all the columns.

# %%
Chipo.columns.tolist()
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### 7) Which was the most-ordered item?

# %%
Chipo.groupby("item_name")['quantity'].sum().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### 8) For the most-ordered item, how many items were ordered?

# %%
Chipo.groupby("item_name")['quantity'].sum().max()
# Out:
# 761

# %% [markdown]
# ### 9) What was the most ordered item in the choice_description column?

# %%
Chipo['choice_description'].value_counts().idxmax()
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### 10) How many items were ordered in total?

# %%
len(Chipo['item_name'].unique())
# Out:
# 50

# %% [markdown]
# ### 11) Turn the item price into a float

# %%
Chipo['item_price']=Chipo['item_price'].str.replace("$","").astype(float) 
Chipo.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 Chipo['item_price']=Chipo['item_price'].str.replace("$","").astype(float)
#       2 Chipo.head(5)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError(
#     249         f"Can only use .str accessor with string values, not {inferred_dtype}"
#     250     )
#     251 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values, not floating

# %% [markdown]
# ### 12) How much was the revenue for the period in the dataset?
# #### Revenue will be the sum of quantity * item_price!

# %%
(Chipo['quantity'].astype(float)*Chipo['item_price']).sum()
# Out:
# 39237.02

# %% [markdown]
# ### 13) How many orders were made in the period?

# %%
Chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### 14) What is the average revenue amount per order?

# %%
((Chipo['quantity'].astype(float)*Chipo['item_price'])/Chipo['order_id']).mean()
# Out:
# 0.03252975446919878

# %% [markdown]
# ### 15) How many different items are sold?

# %%
len(Chipo['item_name'].unique())
# Out:
# 50

# %% [markdown]
# ### 16) Show a histogram with number of orders with bill on the x-axis.

# %%
sns.set_style('darkgrid')
sns.histplot(data=Chipo,x="item_price",color='green')
plt.show()
